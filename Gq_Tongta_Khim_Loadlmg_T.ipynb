# %% [markdown]
# <a href="https://colab.research.google.com/github/Sirilak-1447/ImageProcessing/blob/main/Gq_Tongta_Khim_Loadlmg_T.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# prompt: Mount google drive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install pillow-heif
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 35.9 MB/s eta 0:00:00
# ...

# %%
import sys
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
src_path = '/content/drive/MyDrive/Khim_imageclass/'
image = Image.open(src_path + 'IMG_0105.jpeg')
plt.imshow(image)
plt.axis('off')
plt.show()

# %%
folder_path = '/content/drive/MyDrive/Khim_imageclass/'
image = cv2.imread(folder_path + 'IMG_0105.jpeg')

if image is None:
  print('Could not read the image.')
  sys.exit()

img_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb, cmap=None)
plt.show()

cv2.imwrite(folder_path + 'Gq_Tongta_khim_rgb.jpg', img_rgb)
# Out:
# True
